# %% [markdown]
# GRÁFICO evolucion de presupuestos con aumento en 2024

# %%
import pandas as pd
import matplotlib.pyplot as plt


ruta_relativa = '../dataset/presupuesto_antas_1985_2021.csv'
presupuestos = pd.read_csv(ruta_relativa, sep=",", encoding="ISO-8859-1")
presupuestos.loc[0] = [2022, 4453453.34, 0, 4345654.54, 0]
plt.figure(figsize=(10,6))

# Utilizando los nombres de las columnas proporcionados
plt.plot(presupuestos['Año'], presupuestos['Total Ingresos'], marker="o", linestyle="-", label="Total Ingresos")
plt.plot(presupuestos['Año'], presupuestos['Total Gastos'], marker="o", linestyle="--", label="Total Gastos")

plt.title("Evolución del presupuesto con los ingresos de entrada y anuales")
plt.xlabel("Año")
plt.ylabel("Euros")
plt.grid(True, which="both", ls="--", c='0.65')
plt.legend()
plt.tight_layout()
plt.show()

11965578.747
# Out:
# 11965578.747

# %%
import pandas as pd
import matplotlib.pyplot as plt

ruta_relativa = '../dataset/presupuesto_antas_1985_2021.csv'
presupuestos = pd.read_csv(ruta_relativa, sep=",", encoding="ISO-8859-1")
presupuestos.loc[0] = [2022, 4453453.34, 0, 4345654.54, 0] 

# Añadiendo el monto para el año 2024
nuevo_registro = pd.DataFrame({
    'Año': [2024],
    'Total Ingresos': [11965578.747],
    'Total Gastos': [None]  # Puedes poner el valor que corresponda aquí
    # Nota: Tienes dos columnas con el mismo nombre '%', deberías corregir eso
})

presupuestos = pd.concat([presupuestos, nuevo_registro], ignore_index=True).sort_values(by='Año')

plt.figure(figsize=(10,6))

# Utilizando los nombres de las columnas proporcionados
plt.plot(presupuestos['Año'], presupuestos['Total Ingresos'], marker="o", linestyle="-", label="Total Ingresos")
plt.plot(presupuestos['Año'], presupuestos['Total Gastos'], marker="o", linestyle="--", label="Total Gastos")

# Para conectar el último punto conocido de "Total Ingresos" con el 2024
ultimo_punto_conocido = presupuestos[presupuestos['Año'] == 2022]['Total Ingresos'].values[0]
plt.plot([2022, 2024], [ultimo_punto_conocido, 11965578.747], color='blue', linestyle='-')

plt.title("Evolución del presupuesto con los ingresos de entrada y anuales")
plt.xlabel("Año")
plt.ylabel("Euros")
plt.grid(True, which="both", ls="--", c='0.65')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_5836\4082342631.py:16: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   presupuestos = pd.concat([presupuestos, nuevo_registro], ignore_index=True).sort_values(by='Año')

# %%
import pandas as pd
import matplotlib.pyplot as plt

ruta_relativa = '../dataset/presupuesto_antas_1985_2021.csv'
presupuestos = pd.read_csv(ruta_relativa, sep=",", encoding="ISO-8859-1")
presupuestos.loc[0] = [2022, 4453453.34, 0, 4345654.54, 0] 

# Añadiendo los montos para los años 2024, 2025, 2026 y 2027
nuevos_registros = pd.DataFrame({
    'Año': [2024, 2025, 2026, 2027],
    'Total Ingresos': [11965578.747, None, None, None],
    'Total Gastos': [6370757, 6370757, 6370757, 6370757]
})

presupuestos = pd.concat([presupuestos, nuevos_registros], ignore_index=True).sort_values(by='Año')

plt.figure(figsize=(10,6))

# Utilizando los nombres de las columnas proporcionados
plt.plot(presupuestos['Año'], presupuestos['Total Ingresos'], marker="o", linestyle="-", label="Total Ingresos")
plt.plot(presupuestos['Año'], presupuestos['Total Gastos'], marker="o", linestyle="--", label="Total Gastos")

plt.title("Evolución del presupuesto con los ingresos de entrada y anuales")
plt.xlabel("Año")
plt.ylabel("Euros")
plt.grid(True, which="both", ls="--", c='0.65')
plt.legend()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

ruta_relativa = '../dataset/presupuesto_antas_1985_2021.csv'
presupuestos = pd.read_csv(ruta_relativa, sep=",", encoding="ISO-8859-1")
presupuestos.loc[0] = [2022, 4453453.34, 0, 4345654.54, 0]

# Añadiendo los montos para los años 2024, 2025, 2026 y 2027
nuevos_registros = pd.DataFrame({
    'Año': [2024, 2025, 2026, 2027, 2029, 2030, 2031, 2032, 2033, 2034],
    'Total Ingresos': [11965578.747, None, None, None, None, None, None, None, None, None],
    'Total Gastos': [6370757, 6370757, 6370757, 6370757, 4500000, 4500000, 4500000, 4500000, 4500000, 4500000]
})

presupuestos = pd.concat([presupuestos, nuevos_registros], ignore_index=True).sort_values(by='Año')

plt.figure(figsize=(10,6))

# Utilizando los nombres de las columnas proporcionados
plt.plot(presupuestos['Año'], presupuestos['Total Ingresos'], marker="o", linestyle="-", label="Total Ingresos")
plt.plot(presupuestos['Año'], presupuestos['Total Gastos'], marker="o", linestyle="--", label="Total Gastos")

plt.title("Evolución del presupuesto con los ingresos de entrada y anuales")
plt.xlabel("Año")
plt.ylabel("Euros")
plt.grid(True, which="both", ls="--", c='0.65')
plt.legend()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

ruta_relativa = '../dataset/presupuesto_antas_1985_2021.csv'
presupuestos = pd.read_csv(ruta_relativa, sep=",", encoding="ISO-8859-1")
presupuestos.loc[0] = [2022, 4453453.34, 0, 4345654.54, 0] 

# Añadiendo los montos para los años 2024, 2025, 2026 y 2027
nuevos_registros = pd.DataFrame({
    'Año': [2024, 2025, 2026, 2027],
    'Total Ingresos': [11965578.747, None, None, None],
    'Total Gastos': [6370757, 6370757, 6370757, 6370757]
})

presupuestos = pd.concat([presupuestos, nuevos_registros], ignore_index=True).sort_values(by='Año')

# Llenar los valores faltantes en 'Total Ingresos' y sumar 352000
presupuestos['Total Ingresos'] = presupuestos['Total Ingresos'].combine_first(presupuestos['Total Gastos'] + 352000)
presupuestos['Total Ingresos'] = presupuestos['Total Ingresos'] + 352000

plt.figure(figsize=(10,6))
plt.plot(presupuestos['Año'], presupuestos['Total Ingresos'], marker="o", linestyle="-", label="Total Ingresos")
plt.plot(presupuestos['Año'], presupuestos['Total Gastos'], marker="o", linestyle="--", label="Total Gastos")

plt.title("Evolución del presupuesto con los ingresos de entrada y anuales")
plt.xlabel("Año")
plt.ylabel("Euros")
plt.grid(True, which="both", ls="--", c='0.65')
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Datos del gráfico
infraestructuras = [
    "piscina pública", 
    "Pabellón",
    "construcción de nuevos parques",
    "Cine",
    "residencia de Ancianos",
    "teatro",
    "parques y espacios verdes con wifi",
    "mejora de infraestructuras tecnológicas",
    "modernización de infraestructuras",
    "mercado local",
    "rutas de senderismo",
    "Gymnasio",
    "mejora de las carreteras del polígono",
    "mayor conexión de autobuses con las aldeas"
]
valores = [93, 120, 90, 20, 64, 9, 48, 26, 38, 11, 23, 20, 32, 58]
porcentajes = ["45.8%", "59.1%", "44.3%", "9.9%", "31.5%", "4.4%", "23.6%", "12.8%", "18.7%", "5.4%", "11.3%", "9.9%", "15.8%", "28.6%"]

# Creación del gráfico
plt.figure(figsize=(12, 10))
bars = plt.barh(infraestructuras, valores, color='purple')
plt.xlabel('Número de respuestas')
plt.title('¿Cuál de estas infraestructuras crees que son las más urgentes?')
plt.gca().invert_yaxis()  # invertir eje y para que la barra más alta aparezca en la parte superior

# Añadir etiquetas a cada barra
for bar, porcentaje in zip(bars, porcentajes):
    plt.text(bar.get_width() - (0.02 * max(valores)), bar.get_y() + bar.get_height()/2, 
             f'{porcentaje} ({int(bar.get_width())})', 
             va='center', ha='right', color='white', fontsize=10)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Configuración inicial
años = list(range(2023, 2044))
gastos_anuales = []

# Simulación de gastos
for año in años:
    gastos_mensuales = np.random.uniform(100, 140, 12)  # Generamos 12 valores aleatorios para cada mes
    gasto_anual = gastos_mensuales.sum()
    gastos_anuales.append(gasto_anual)

# Gráfico de línea
plt.figure(figsize=(10,6))
plt.plot(años, gastos_anuales, marker='o')
plt.title('Gasto anual total por familia (2023-2043)')
plt.xlabel('Año')
plt.ylabel('Gasto Anual (€)')
plt.ylim(0, 2000)  # Establecemos el límite del eje y
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Configuración inicial
años = list(range(2023, 2044))
gastos_anuales = []

# Simulación de gastos
for año in años:
    gastos_mensuales = np.random.uniform(100, 140, 12)  # Generamos 12 valores aleatorios para cada mes
    gasto_anual = gastos_mensuales.sum()
    gastos_anuales.append(gasto_anual)

# Calculo de gastos acumulados
gastos_acumulados = np.cumsum(gastos_anuales)

# Gráfico de línea
plt.figure(figsize=(10,6))
plt.plot(años, gastos_acumulados, marker='o')
plt.title('Gasto acumulado por familia (2023-2043)')
plt.xlabel('Año')
plt.ylabel('Gasto Acumulado (€)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Configuración inicial
años = list(range(2023, 2044))
unidades_familiares = 1179
gastos_anuales_totales = []

# Simulación de gastos
for año in años:
    gastos_mensuales = np.random.uniform(100, 140, 12)  # Generamos 12 valores aleatorios para cada mes
    gasto_anual = gastos_mensuales.sum() * unidades_familiares  # Multiplicamos por las unidades familiares
    gastos_anuales_totales.append(gasto_anual)

# Gráfico de línea
plt.figure(figsize=(10,6))
plt.plot(años, gastos_anuales_totales, marker='o')
plt.title('Gasto anual total por todas las familias (2023-2043)')
plt.xlabel('Año')
plt.ylabel('Gasto Anual Total (€)')
plt.ylim(0, 2000000)  # Ajuste de la escala desde 0 hasta 2 millones
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Calculo de gastos acumulados
gastos_acumulados_totales = np.cumsum(gastos_anuales_totales)

# Gráfico de línea
plt.figure(figsize=(10,6))
plt.plot(años, gastos_acumulados_totales, marker='o')
plt.title('Gasto acumulado por todas las familias (2023-2043)')
plt.xlabel('Año')
plt.ylabel('Gasto Acumulado Total (€)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Datos iniciales
años = list(range(2023, 2044))
gastos_anuales = [1520.42, 1471.42, 1497.41, 1515.12, 1500.36, 1501.87, 1521.23, 1487.37, 1505.76, 1510.29, 1496.83, 1508.13, 1510.93, 1512.35, 1503.28, 1512.44, 1500.62, 1501.48, 1520.15, 1504.62, 1499.61]
gasto_constante = [254.21] * len(años)  # Gasto constante de 254.21€ por familia al año

# Crear el gráfico
plt.figure(figsize=(10,6))
plt.plot(años, gastos_anuales, marker='o', label="Gasto actual")
plt.plot(años, gasto_constante, linestyle='--', color='red', label="Gasto constante 254.21€")
plt.title('Comparación de gasto anual por familia (2023-2043)')
plt.xlabel('Año')
plt.ylabel('Gasto Anual (€)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Definiendo las variables
years = list(range(2023, 2044))  # desde 2023 hasta 2043 inclusive
gasto_actual = [960] * len(years)  # 1400€ cada año
gasto_constante = [254.21] * len(years)  # 254.21€ cada año

# Sumando los gastos acumulados año tras año
cumulative_gasto_actual = [sum(gasto_actual[:i+1]) for i in range(len(years))]
cumulative_gasto_constante = [sum(gasto_constante[:i+1]) for i in range(len(years))]

# Creando el gráfico
plt.figure(figsize=(10, 6))
plt.plot(years, cumulative_gasto_actual, label="Gasto actual acumulado", marker='o')
plt.plot(years, cumulative_gasto_constante, label="Gasto constante 254.21€ acumulado", linestyle='--', color='red', marker='x')
plt.xlabel("Año")
plt.ylabel("Gasto Acumulado (€)")
plt.title("Comparación del Gasto Acumulado por Familia (2023-2043)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# segun red electrica una casa promedio consume 9 kwh al dia en españa

# %%
consumo_medio_dia= 9
consumo_medio_mes=9*30.5
consumo_medio_año=consumo_medio_mes*12
print(consumo_medio_mes,consumo_medio_año)
"""274.5 kW = 0.2745 MW
3294.0 kW = 3.294 MW"""

placas= 180*6
inversor=1400
bateria=2000
intalación=300

coste_instalacion_promedio=placas+inversor+bateria+intalación

print(coste_instalacion_promedio)
# Out:
# 274.5 3294.0
# 4780

# %%
import matplotlib.pyplot as plt

# Datos iniciales
potencia_pico = 250  # MWp
horas_solares_pico = 2250  # horas al año
tasa_degradacion = 0.005  # 0.5% al año

# Lista para almacenar la energía generada cada año
energias = []

# Calcular la energía generada cada año teniendo en cuenta la degradación
energia_inicial = potencia_pico * horas_solares_pico
for año in range(2026, 2047):
    energias.append(energia_inicial)
    energia_inicial *= (1 - tasa_degradacion)  # Disminuir la energía generada por la tasa de degradación

# Graficar
años = list(range(2026, 2047))
plt.figure(figsize=(10, 6))
plt.plot(años, energias, marker='o')
plt.title('Energía generada por una central solar de 250 MWp (2026-2046)')
plt.xlabel('Año')
plt.ylabel('Energía generada (MWh)')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Datos proporcionados
años = list(range(2008, 2022))
deuda = [1.1, 1.6, 1.4, 1.1, 2.3, 2.5, 2.1, 2.0, 1.8, 1.5, 1.1, 1.9, 1.6, 1.8]

# Extendiendo datos hasta que la deuda sea 0
año_actual = 2022
while deuda[-1] > 0:
    años.append(año_actual)
    if año_actual <= 2024:
        deuda.append(deuda[-1])  # Mantener la deuda igual hasta 2024
    else:
        deuda.append(max(0, deuda[-1] - 0.3))  # Reducir la deuda en 0.3 millones cada año a partir de 2025
    año_actual += 1

# Creando el gráfico
plt.figure(figsize=(12, 7))
plt.plot(años, deuda, marker='o', color='b', linestyle='-')
plt.title('Deuda Pública en Millones de Euros')
plt.xlabel('Año')
plt.ylabel('Deuda en Millones de Euros')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()

# Mostrando el gráfico
plt.show()
